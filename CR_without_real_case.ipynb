# %% [markdown]
# # Installation

# %%
pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading pgeocode-0.3.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pgeocode) (2.23.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pgeocode) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2.10)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.3.0

# %%
pip install polyline
# Out:
# Collecting polyline
#   Downloading polyline-1.4.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from polyline) (1.15.0)
# Installing collected packages: polyline
# Successfully installed polyline-1.4.0

# %% [markdown]
# # Import libraries

# %%
#HTTP requests for python
import requests
import json
import polyline
import datetime
#Webscraping with BeautifulSoup
from bs4 import BeautifulSoup
#Data manipulation
import pandas as pd
#Postal code geocoding and distance calculations
import pgeocode
#Maps
import folium

# %% [markdown]
# # Data Cleaning

# %%
url ='https://en.wikipedia.org/wiki/Postal_codes_in_Costa_Rica'

df = pd.read_html(url)[0]

# %%
df.head()
# Out:
#    Province    Canton  District  PostalCode
# 0  San José  San José    Carmen       10101
# 1  San José  San José    Merced       10102
# 2  San José  San José  Hospital       10103
# 3  San José  San José  Catedral       10104
# 4  San José  San José    Zapote       10105

# %%
df['Province'].unique()
# Out:
# array(['San José', 'Alajuela', 'Cartago', 'Heredia', 'Guanacaste',
#        'Puntarenas', 'Limón'], dtype=object)

# %%
 'Puerto Viejo' in df['District'].unique()
# Out:
# True

# %%
country = pgeocode.Nominatim('cr')

# %%
def lat(x):

  return country.query_postal_code(x)['latitude']

def long(x):

  return country.query_postal_code(x)['longitude']

# %%
df['latitude'] = df['PostalCode'].map(lambda x: lat(x) )
df['longitude'] = df['PostalCode'].map(lambda x: long(x) )

# %%
df = df.dropna(subset=['longitude'])
df = df.dropna(subset=['latitude'])

# %%
df.head()
# Out:
#    Province    Canton  District  PostalCode  latitude  longitude
# 0  San José  San José    Carmen       10101    9.9364   -84.0693
# 1  San José  San José    Merced       10102    9.9397   -84.0884
# 2  San José  San José  Hospital       10103    9.9277   -84.0887
# 3  San José  San José  Catedral       10104    9.9262   -84.0731
# 4  San José  San José    Zapote       10105    9.9205   -84.0598

# %% [markdown]
# # Map of Districts in Costa Rica

# %%
# monteverde coordinates

latitude , longitude = 10.31792333245692,-84.79402582701236

map_cr = folium.Map(location=[latitude, longitude], zoom_start=10)
    
folium.CircleMarker(
        location = [latitude, longitude],
        radius=10,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)

for index,row in df.iterrows():

      lat = row['latitude']
      lng = row['longitude']
      label = row['District']
      folium.CircleMarker(
        location = [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_cr)       


map_cr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7d5b737c91bc4a8cac62cc08d44d6a7c%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7d5b737c91bc4a8cac62cc08d44d6a7c%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7d5b737c91bc4a8cac62cc08d44d6a7c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7d5b737c91bc4a8cac62cc08d44d6a7c%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B10.31792333245692%2C%20-84.79402582701236%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_002d1a79329f47e1a13aaaa5b6cda7ab%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# # Travel time example

# %%
# # long , lat format

# p1= "-84.0693,9.9364"
# p2= "-84.79402582701236,10.31792333245692"


# url = "http://router.project-osrm.org/route/v1/car/"+p1+";"+p2+"?overview=false"
# r = requests.get(url)

# routes = json.loads(r.content)
# route_i = routes.get("routes")[0]

# %% [markdown]
# Return the duration of the travel in seconds

# %%
#route_i["duration"]

# %%
#Results checked
#str(datetime.timedelta(seconds=route_i["duration"]))

# %%
def durations(p1,p2):
  url = "http://router.project-osrm.org/route/v1/car/"+p1+";"+p2+"?overview=false"
    
  r = requests.get(url)
  routes = json.loads(r.content)
  route_i = routes.get("routes")[0]
  return route_i["duration"]

# %%
list_lng = df['longitude'].tolist()
list_lat = df['latitude'].tolist()

coord = []

for i in range(len(df)):

  coord.append(str(list_lng[i])+','+str(list_lat[i]))

df['coordinates'] = coord

df.head()
# Out:
#    Province    Canton  District  ...  latitude  longitude      coordinates
# 0  San José  San José    Carmen  ...    9.9364   -84.0693  -84.0693,9.9364
# 1  San José  San José    Merced  ...    9.9397   -84.0884  -84.0884,9.9397
# 2  San José  San José  Hospital  ...    9.9277   -84.0887  -84.0887,9.9277
# 3  San José  San José  Catedral  ...    9.9262   -84.0731  -84.0731,9.9262
# 4  San José  San José    Zapote  ...    9.9205   -84.0598  -84.0598,9.9205
#
# [5 rows x 7 columns]

# %%
#p2 is the place we want to visit

#monteverde example

#p2 = "-84.79402582701236,10.31792333245692"

#df['duration'] = df['coordinates'].map(lambda x: durations(x,p2) )

# %% [markdown]
# Now, we have a dataset with the travel time beetween a place "p2" and districs

# %%
#df.head()

# %% [markdown]
# # Best Route

# %% [markdown]
# Given some places we want to know what are the best hotels in order to minimize travel time. We must make some assumtions in order to answer the question.

# %% [markdown]
# <table>
#   <tr>
#     <td>Place</td>
#     <td>Longitude</td>
#     <td>Latitude</td>
#   </tr>
#   <tr>
#     <td>Airport</td>
#     <td>-84.204</td>
#     <td>9.997</td>
#   </tr>
# <tr>
#     <td>Volcan de Póas</td>
#     <td>-84.242</td>
#     <td>10.196</td>
#   </tr>
# <tr>
#     <td>Monteverde</td>
#     <td>-84.794</td>
#     <td>10.317</td>
#   </tr>
# <tr>
#     <td>Tapati</td>
#     <td>-83.777</td>
#     <td>9.761</td>
#   </tr>
# <tr>
#     <td>Corcovado</td>
#     <td>-83.558</td>
#     <td>8.566</td>
#   </tr>

# %%
#longitude latitude format
airport = "-84.2041127746699,9.997933974047806"
volcan_poas= "-84.24278716302729,10.196943409958461"
monteverde = "-84.79402582701236,10.31792333245692"
tapati = "-83.77709939226695,9.761592197168095"
corcovado = "-83.55879213348997,8.566233468363677"


df['d_airport'] = df['coordinates'].map(lambda x: durations(x,airport) )
df['d_volcan_poás'] = df['coordinates'].map(lambda x: durations(x,volcan_poas) )
df['d_monteverde'] = df['coordinates'].map(lambda x: durations(x,monteverde) )
df['d_tapati'] = df['coordinates'].map(lambda x: durations(x,tapati) )
df['d_corcovado'] = df['coordinates'].map(lambda x: durations(x,corcovado) )

# %%
df.head()
# Out:
#    Province    Canton  District  ...  d_monteverde  d_tapati  d_corcovado
# 0  San José  San José    Carmen  ...       11408.5    4810.8      22572.8
# 1  San José  San José    Merced  ...       11133.2    5061.0      22633.0
# 2  San José  San José  Hospital  ...       11253.4    4969.0      22477.1
# 3  San José  San José  Catedral  ...       11396.7    4740.2      22325.3
# 4  San José  San José    Zapote  ...       11612.5    4534.0      22304.6
#
# [5 rows x 12 columns]

# %% [markdown]
# We need to simplify the problem. We will work with the 5 closest districts to each place. This is a nice assumption, it is prefered lower travel times beetwen hotels and places. The travel times between hotels are less important.

# %%
df_simplified = pd.concat([df.nsmallest(3,'d_airport'),df.nsmallest(3,'d_volcan_poás'),df.nsmallest(3,'d_monteverde'),df.nsmallest(3,'d_tapati'),df.nsmallest(3,'d_corcovado')], ignore_index=True)

# %%
df_simplified
# Out:
#       Province      Canton  ... d_tapati  d_corcovado
# 0     Alajuela    Alajuela  ...   6142.0      22396.1
# 1     Alajuela    Alajuela  ...   6383.3      22595.1
# 2      Heredia      Flores  ...   5858.2      22720.3
# 3     Alajuela        Poás  ...   8421.9      24641.1
# 4     Alajuela      Grecia  ...   8790.0      24104.5
# 5     Alajuela        Poás  ...   8308.8      24270.0
# 6   Puntarenas  Puntarenas  ...  15321.3      26108.8
# 7   Guanacaste   Abangares  ...  15789.1      26576.6
# 8   Guanacaste     Tilarán  ...  16916.0      27703.5
# 9      Cartago     Cartago  ...   1972.5      25206.4
# 10     Cartago     Cartago  ...   2362.6      24060.5
# 11     Cartago     Paraíso  ...   2633.4      24359.9
# 12  Puntarenas     Golfito  ...  26842.3       4106.2
# 13  Puntarenas         Osa  ...  23612.8       4966.9
# 14  Puntarenas         Osa  ...  21259.2       5213.1
#
# [15 rows x 12 columns]

# %% [markdown]
# Now we calculate the travel time between these options

# %%
for i in range(len(df_simplified)):

  l=[]

  for j in range(len(df_simplified)):

    p1 = df_simplified['coordinates'][i]
    p2 = df_simplified['coordinates'][j]

    if i==j :

      l.append(0)

    else:

      l.append(durations(p1,p2))

  df_simplified['x'+str(i)] = l

# %%
durations('-84.2144,10.1427','-84.8248,10.2914' )
# Out:
# 11550.3

# %%
df_simplified
# Out:
#       Province      Canton         District  ...      x12      x13      x14
# 0     Alajuela    Alajuela      Río Segundo  ...  23075.7  19846.2  17492.6
# 1     Alajuela    Alajuela         Alajuela  ...  23318.4  20088.9  17735.3
# 2      Heredia      Flores         Llorente  ...  23408.7  20179.2  17825.6
# 3     Alajuela        Poás   Sabana Redonda  ...  25348.2  22118.7  19765.1
# 4     Alajuela      Grecia       San Isidro  ...  24734.4  21504.9  19151.3
# 5     Alajuela        Poás         San Juan  ...  25069.8  21840.3  19486.7
# 6   Puntarenas  Puntarenas      Monte Verde  ...  26974.1  23744.6  21391.0
# 7   Guanacaste   Abangares           Sierra  ...  27450.7  24221.2  21867.6
# 8   Guanacaste     Tilarán  Quebrada Grande  ...  28572.1  25342.6  22989.0
# 9      Cartago     Cartago     Aguacaliente  ...  26034.6  22805.1  20451.5
# 10     Cartago     Cartago     Dulce Nombre  ...  24893.4  21663.9  19310.3
# 11     Cartago     Paraíso          Paraíso  ...  25123.9  21894.4  19540.8
# 12  Puntarenas     Golfito   Puerto Jiménez  ...      0.0   5773.6   6019.8
# 13  Puntarenas         Osa           Sierpe  ...   5775.6      0.0   5439.7
# 14  Puntarenas         Osa  Piedras Blancas  ...   6021.1   5434.6      0.0
#
# [15 rows x 27 columns]

# %%
lnga,lata = -84.2041127746699,9.997933974047806
lngv,latv = -84.24278716302729,10.196943409958461
lngm,latm  = -84.79402582701236,10.31792333245692
lngt,latt  = -83.77709939226695,9.761592197168095
lngc,latc = -83.55879213348997,8.566233468363677

map_cr = folium.Map(location=[lata, lnga], zoom_start=10)
    
folium.CircleMarker(
        location = [lata, lnga],
        radius=15,
        popup= 'Airport',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)

folium.CircleMarker(
        location = [latv, lngv],
        radius=15,
        popup= 'Volcan',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)

folium.CircleMarker(
        location = [latm, lngm],
        radius=15,
        popup= 'Monteverde',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)

folium.CircleMarker(
        location = [latt, lngt],
        radius=15,
        popup= 'Tapati',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)  

folium.CircleMarker(
        location = [latc, lngc],
        radius=15,
        popup= 'Corcovado',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_cr)        

for index,row in df_simplified.iterrows():

      lat = row['latitude']
      lng = row['longitude']
      label = row['District']
      folium.CircleMarker(
        location = [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_cr)       


map_cr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_e777a99ca25b475197a8e9cfbab154dd%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e777a99ca25b475197a8e9cfbab154dd%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_e777a99ca25b475197a8e9cfbab154dd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_e777a99ca25b475197a8e9cfbab154dd%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B9.997933974047806%2C%20-84.2041127746699%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7c312e36f3d141dfbc70132e0b545e48%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A ...

# %% [markdown]
# # Optimization with Simplex Method
#
# If we have a simplified example we can apply simplex method in order to solve our transport optimization.

# %%
df_simplified.to_excel('v0_costa_rica.xls')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **xi** : Hotel in district i , 0 <= **x** <=1
#
# ---
#
# **MIN** z = SUM( duration between x [ i ] and place[ i ]) + SUM( duration between x [ day j ] and x [ day j+1 ])
#
# ---
#
#
# We apply a simplification in the calculation of the time between hotels, the problem is to big to make a real objective function in Excel.
#
# We sum the means of going to the hotel for the next day.
#
#
# **MIN**  *z = SUM( xi · dpi ) +  SUM{ mean( (dx0·x3+dx0·x4+dx0·x5)+(dx1·x3+dx1·x4+dx1·x5)+... ) + mean( (dx3·x6 + dx3 ·x7+ dx3· x8) + ... ) }*
#
# ---
# For each location we can only choose one hotel
#
# **Subject to** :
#
# x0+x1+x2   = 1
#
# x3+x4+x5   = 1
#
# x6+x7+x8   = 1
#
# x9+x10+x11 = 1
#
# x12+x13+x14  =  1

# %% [markdown]
# # Best Route Algorithm

# %% [markdown]
# Create all possible routes. First of all we need to do some preprocess.

# %%
def set_index_labels(df,num_labels):

  indexs = {}

  for i in range(num_labels):

   indexs[i] = '_x'+str(i)

  return df.rename(index=indexs)

# %%
def create_variables(num_vars):

  vars = []

  for i in range(num_vars):

    vars.append('x'+str(i))

  return vars

# %%
 _df = set_index_labels(df_simplified,15)

 _df
# Out:
#         Province      Canton         District  ...      x12      x13      x14
# _x0     Alajuela    Alajuela      Río Segundo  ...  23075.7  19846.2  17492.6
# _x1     Alajuela    Alajuela         Alajuela  ...  23318.4  20088.9  17735.3
# _x2      Heredia      Flores         Llorente  ...  23408.7  20179.2  17825.6
# _x3     Alajuela        Poás   Sabana Redonda  ...  25348.2  22118.7  19765.1
# _x4     Alajuela      Grecia       San Isidro  ...  24734.4  21504.9  19151.3
# _x5     Alajuela        Poás         San Juan  ...  25069.8  21840.3  19486.7
# _x6   Puntarenas  Puntarenas      Monte Verde  ...  26974.1  23744.6  21391.0
# _x7   Guanacaste   Abangares           Sierra  ...  27450.7  24221.2  21867.6
# _x8   Guanacaste     Tilarán  Quebrada Grande  ...  28572.1  25342.6  22989.0
# _x9      Cartago     Cartago     Aguacaliente  ...  26034.6  22805.1  20451.5
# _x10     Cartago     Cartago     Dulce Nombre  ...  24893.4  21663.9  19310.3
# _x11     Cartago     Paraíso          Paraíso  ...  25123.9  21894.4  19540.8
# _x12  Puntarenas     Golfito   Puerto Jiménez  ...      0.0   5773.6   6019.8
# _x13  Puntarenas         Osa           Sierpe  ...   5775.6      0.0   5439.7
# _x14  Puntarenas         Osa  Piedras Blancas  ...   6021.1   5434.6      0.0
#
# [15 rows x 27 columns]

# %%
_df['x0']['_x1']
# Out:
# 414.4

# %%
hotels
# Out:
# ['x0',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14']

# %%
import itertools

hotels = create_variables(15)

for x in itertools.combinations(hotels, 5):

    if ((x[0] == 'x3') or (x[0] == 'x4') or (x[0] == 'x5')) and ((x[1] == 'x6') or (x[1] == 'x7') or (x[1] == 'x8')) and ((x[2] == 'x9') or (x[2] == 'x10') or (x[2] == 'x11')) and ((x[3] == 'x12') or (x[3] == 'x13') or (x[3] == 'x14')) and ((x[4] == 'x0') or (x[4] == 'x1') or (x[4] == 'x2')):

      print(x)

# %%
import itertools

def best_route_v0(hotels,places, df):

  comb = ()

  min = 10000000000

  for x in itertools.combinations(hotels, len(places) ):

    #We could adapt de code only modifying the conditional

    if ((x[0] == 'x0') or (x[0] == 'x1') or (x[0] == 'x2')) and ((x[1] == 'x3') or (x[1] == 'x4') or (x[1] == 'x5')) and ((x[2] == 'x6') or (x[2] == 'x7') or (x[2] == 'x8')) and ((x[3] == 'x9') or (x[3] == 'x10') or (x[3] == 'x11')) and ((x[4] == 'x12') or (x[4] == 'x13') or (x[4] == 'x14')) :

      #calculate the duration beetween hotels and locations

      duration_h_p = 0

      for i in range(len(places)):

        duration_h_p = duration_h_p + df[places[i]]['_'+x[i]]

      #calculate the duration beetween hotels

      duration_hotels = 0

      for i in range(len(x)-1):

        if i != 0:

          duration_hotels = duration_hotels + df[x[i]]['_'+x[i+1]]

        else:

          pass

      duration_hotels = duration_hotels + df[x[-1]]['_'+x[0]]
         

      if (duration_hotels+duration_h_p) < min :

        min = (duration_hotels+duration_h_p)

        comb = x

    else:

      pass


  return comb,min

# %%
for x in itertools.combinations(hotels, 5):

    if ((x[0] == 'x0') or (x[0] == 'x1') or (x[0] == 'x2')) and ((x[1] == 'x3') or (x[1] == 'x4') or (x[1] == 'x5')) and ((x[2] == 'x6') or (x[2] == 'x7') or (x[2] == 'x8')) and ((x[3] == 'x9') or (x[3] == 'x10') or (x[3] == 'x11')) and ((x[4] == 'x12') or (x[4] == 'x13') or (x[4] == 'x14')) :

      print(x)
# Out:
# ('x0', 'x3', 'x6', 'x9', 'x12')
# ('x0', 'x3', 'x6', 'x9', 'x13')
# ('x0', 'x3', 'x6', 'x9', 'x14')
# ('x0', 'x3', 'x6', 'x10', 'x12')
# ('x0', 'x3', 'x6', 'x10', 'x13')
# ('x0', 'x3', 'x6', 'x10', 'x14')
# ('x0', 'x3', 'x6', 'x11', 'x12')
# ('x0', 'x3', 'x6', 'x11', 'x13')
# ('x0', 'x3', 'x6', 'x11', 'x14')
# ('x0', 'x3', 'x7', 'x9', 'x12')
# ('x0', 'x3', 'x7', 'x9', 'x13')
# ('x0', 'x3', 'x7', 'x9', 'x14')
# ('x0', 'x3', 'x7', 'x10', 'x12')
# ('x0', 'x3', 'x7', 'x10', 'x13')
# ('x0', 'x3', 'x7', 'x10', 'x14')
# ('x0', 'x3', 'x7', 'x11', 'x12')
# ('x0', 'x3', 'x7', 'x11', 'x13')
# ('x0', 'x3', 'x7', 'x11', 'x14')
# ('x0', 'x3', 'x8', 'x9', 'x12')
# ('x0', 'x3', 'x8', 'x9', 'x13')
# ('x0', 'x3', 'x8', 'x9', 'x14')
# ('x0', 'x3', 'x8', 'x10', 'x12')
# ('x0', 'x3', 'x8', 'x10', 'x13')
# ('x0', 'x3', 'x8', 'x10', 'x14')
# ('x0', 'x3', 'x8', 'x11', 'x12')
# ('x0', 'x3', 'x8', 'x11', 'x13')
# ('x0', 'x3', 'x8', 'x11', 'x14')
# ('x0', 'x4', 'x6', 'x9', 'x12')
# ('x0', 'x4', 'x6', 'x9', 'x13')
# ('x0', 'x4', 'x6', 'x9', 'x14')
# ('x0', 'x4', 'x6', 'x10', 'x12')
# ('x0', 'x4', 'x6', 'x10', 'x13')
# ('x0', 'x4', 'x6', 'x10', 'x14')
# ('x0', 'x4', 'x6', 'x11', 'x12')
# ('x0', 'x4', 'x6', 'x11', 'x13')
# ('x0', 'x4', 'x6', 'x11', 'x14')
# ('x0', 'x4', 'x7', 'x9', 'x12')
# ('x0', 'x4', 'x7', 'x9', 'x13')
# ('x0', 'x4', 'x7', 'x9', 'x14')
# ('x0', 'x4', 'x7', 'x10', 'x12')
# ('x0', 'x4', 'x7', 'x10', 'x13')
# ('x0', 'x4', 'x7', 'x10', 'x14')
# ('x0', 'x4', 'x7', 'x11', 'x12')
# ('x0', 'x4', 'x7', 'x11', 'x13')
# ('x0', 'x4', 'x7', 'x11', 'x14')
# ('x0', 'x4', 'x8', 'x9', 'x12')
# ('x0', 'x4', 'x8', 'x9', 'x13')
# ('x0', 'x4', 'x8', 'x9', 'x14')
# ('x0', 'x4', 'x8', 'x10', 'x12')
# ('x0', 'x4', 'x8', 'x10', 'x13')
# ('x0', 'x4', 'x8', 'x10', 'x14')
# ('x0', 'x4', 'x8', 'x11', 'x12')
# ('x0', 'x4', 'x8', 'x11', 'x13')
# ('x0', 'x4', 'x8', 'x11', 'x14')
# ('x0', 'x5', 'x6', 'x9', 'x12')
# ('x0', 'x5', 'x6', 'x9', 'x13')
# ('x0', 'x5', 'x6', 'x9', 'x14')
# ('x0', 'x5', 'x6', 'x10', 'x12')
# ('x0', 'x5', 'x6', 'x10', 'x13')
# ('x0', 'x5', 'x6', 'x10', 'x14')
# ('x0', 'x5', 'x6', 'x11', 'x12')
# ('x0', 'x5', 'x6', 'x11', 'x13')
# ('x0', 'x5', 'x6', 'x11', 'x14')
# ('x0', 'x5', 'x7', 'x9', 'x12')
# ('x0', 'x5', 'x7', 'x9', 'x13')
# ('x0', 'x5', 'x7', 'x9', 'x14')
# ('x0', 'x5', 'x7', 'x10', 'x12')
# ('x0', 'x5', 'x7', 'x10', 'x13')
# ('x0', 'x5', 'x7', 'x10', 'x14')
# ('x0', 'x5', 'x7', 'x11', 'x12')
# ('x0', 'x5', 'x7', 'x11', 'x13')
# ('x0', 'x5', 'x7', 'x11', 'x14')
# ('x0', 'x5', 'x8', 'x9', 'x12')
# ('x0', 'x5', 'x8', 'x9', 'x13')
# ('x0', 'x5', 'x8', 'x9', 'x14')
# ('x0', 'x5', 'x8', 'x10', 'x12')
# ('x0', 'x5', 'x8', 'x10', 'x13')
# ('x0', 'x5', 'x8', 'x10', 'x14')
# ('x0', 'x5', 'x8', 'x11', 'x12')
# ('x0', 'x5', 'x8', 'x11', 'x13')
# ('x0', 'x5', 'x8', 'x11', 'x14')
# ('x1', 'x3', 'x6', 'x9', 'x12')
# ('x1', 'x3', 'x6', 'x9', 'x13')
# ('x1', 'x3', 'x6', 'x9', 'x14')
# ('x1', 'x3', 'x6', 'x10', 'x12')
# ('x1', 'x3', 'x6', 'x10', 'x13')
# ('x1', 'x3', 'x6', 'x10', 'x14')
# ('x1', 'x3', 'x6', 'x11', 'x12')
# ('x1', 'x3', 'x6', 'x11', 'x13')
# ('x1', 'x3', 'x6', 'x11', 'x14')
# ('x1', 'x3', 'x7', 'x9', 'x12')
# ('x1', 'x3', 'x7', 'x9', 'x13')
# ('x1', 'x3', 'x7', 'x9', 'x14')
# ('x1', 'x3', 'x7', 'x10', 'x12')
# ('x1', 'x3', 'x7', 'x10', 'x13')
# ('x1', 'x3', 'x7', 'x10', 'x14')
# ('x1', 'x3', 'x7', 'x11', 'x12')
# ('x1', 'x3', 'x7', 'x11', 'x13')
# ('x1', 'x3', 'x7', 'x11', 'x14')
# ('x1', 'x3', 'x8', 'x9', 'x12')
# ('x1', 'x3', 'x8', 'x9', 'x13')
# ('x1', 'x3', 'x8', 'x9', 'x14')
# ('x1', 'x3', 'x8', 'x10', 'x12')
# ('x1', 'x3', 'x8', 'x10', 'x13')
# ('x1', 'x3', 'x8', 'x10', 'x14')
# ('x1', 'x3', 'x8', 'x11', 'x12')
# ('x1', 'x3', 'x8', 'x11', 'x13')
# ('x1', 'x3', 'x8', 'x11', 'x14')
# ('x1', 'x4', 'x6', 'x9', 'x12')
# ('x1', 'x4', 'x6', 'x9', 'x13')
# ('x1', 'x4', 'x6', 'x9', 'x14')
# ('x1', 'x4', 'x6', 'x10', 'x12')
# ('x1', 'x4', 'x6', 'x10', 'x13')
# ('x1', 'x4', 'x6', 'x10', 'x14')
# ('x1', 'x4', 'x6', 'x11', 'x12')
# ('x1', 'x4', 'x6', 'x11', 'x13')
# ('x1', 'x4', 'x6', 'x11', 'x14')
# ('x1', 'x4', 'x7', 'x9', 'x12')
# ('x1', 'x4', 'x7', 'x9', 'x13')
# ('x1', 'x4', 'x7', 'x9', 'x14')
# ('x1', 'x4', 'x7', 'x10', 'x12')
# ('x1', 'x4', 'x7', 'x10', 'x13')
# ('x1', 'x4', 'x7', 'x10', 'x14')
# ('x1', 'x4', 'x7', 'x11', 'x12')
# ('x1', 'x4', 'x7', 'x11', 'x13')
# ('x1', 'x4', 'x7', 'x11', 'x14')
# ('x1', 'x4', 'x8', 'x9', 'x12')
# ('x1', 'x4', 'x8', 'x9', 'x13')
# ('x1', 'x4', 'x8', 'x9', 'x14')
# ('x1', 'x4', 'x8', 'x10', 'x12')
# ('x1', 'x4', 'x8', 'x10', 'x13')
# ('x1', 'x4', 'x8', 'x10', 'x14')
# ('x1', 'x4', 'x8', 'x11', 'x12')
# ('x1', 'x4', 'x8', 'x11', 'x13')
# ('x1', 'x4', 'x8', 'x11', 'x14')
# ('x1', 'x5', 'x6', 'x9', 'x12')
# ('x1', 'x5', 'x6', 'x9', 'x13')
# ('x1', 'x5', 'x6', 'x9', 'x14')
# ('x1', 'x5', 'x6', 'x10', 'x12')
# ('x1', 'x5', 'x6', 'x10', 'x13')
# ('x1', 'x5', 'x6', 'x10', 'x14')
# ('x1', 'x5', 'x6', 'x11', 'x12')
# ('x1', 'x5', 'x6', 'x11', 'x13')
# ('x1', 'x5', 'x6', 'x11', 'x14')
# ('x1', 'x5', 'x7', 'x9', 'x12')
# ('x1', 'x5', 'x7', 'x9', 'x13')
# ('x1', 'x5', 'x7', 'x9', 'x14')
# ('x1', 'x5', 'x7', 'x10', 'x12')
# ('x1', 'x5', 'x7', 'x10', 'x13')
# ('x1', 'x5', 'x7', 'x10', 'x14')
# ('x1', 'x5', 'x7', 'x11', 'x12')
# ('x1', 'x5', 'x7', 'x11', 'x13')
# ('x1', 'x5', 'x7', 'x11', 'x14')
# ('x1', 'x5', 'x8', 'x9', 'x12')
# ('x1', 'x5', 'x8', 'x9', 'x13')
# ('x1', 'x5', 'x8', 'x9', 'x14')
# ('x1', 'x5', 'x8', 'x10', 'x12')
# ('x1', 'x5', 'x8', 'x10', 'x13')
# ('x1', 'x5', 'x8', 'x10', 'x14')
# ('x1', 'x5', 'x8', 'x11', 'x12')
# ('x1', 'x5', 'x8', 'x11', 'x13')
# ('x1', 'x5', 'x8', 'x11', 'x14')
# ('x2', 'x3', 'x6', 'x9', 'x12')
# ('x2', 'x3', 'x6', 'x9', 'x13')
# ('x2', 'x3', 'x6', 'x9', 'x14')
# ('x2', 'x3', 'x6', 'x10', 'x12')
# ('x2', 'x3', 'x6', 'x10', 'x13')
# ('x2', 'x3', 'x6', 'x10', 'x14')
# ('x2', 'x3', 'x6', 'x11', 'x12')
# ('x2', 'x3', 'x6', 'x11', 'x13')
# ('x2', 'x3', 'x6', 'x11', 'x14')
# ('x2', 'x3', 'x7', 'x9', 'x12')
# ('x2', 'x3', 'x7', 'x9', 'x13')
# ('x2', 'x3', 'x7', 'x9', 'x14')
# ('x2', 'x3', 'x7', 'x10', 'x12')
# ('x2', 'x3', 'x7', 'x10', 'x13')
# ('x2', 'x3', 'x7', 'x10', 'x14')
# ('x2', 'x3', 'x7', 'x11', 'x12')
# ('x2', 'x3', 'x7', 'x11', 'x13')
# ('x2', 'x3', 'x7', 'x11', 'x14')
# ('x2', 'x3', 'x8', 'x9', 'x12')
# ('x2', 'x3', 'x8', 'x9', 'x13')
# ('x2', 'x3', 'x8', 'x9', 'x14')
# ('x2', 'x3', 'x8', 'x10', 'x12')
# ('x2', 'x3', 'x8', 'x10', 'x13')
# ('x2', 'x3', 'x8', 'x10', 'x14')
# ('x2', 'x3', 'x8', 'x11', 'x12')
# ('x2', 'x3', 'x8', 'x11', 'x13')
# ('x2', 'x3', 'x8', 'x11', 'x14')
# ('x2', 'x4', 'x6', 'x9', 'x12')
# ('x2', 'x4', 'x6', 'x9', 'x13')
# ('x2', 'x4', 'x6', 'x9', 'x14')
# ('x2', 'x4', 'x6', 'x10', 'x12')
# ('x2', 'x4', 'x6', 'x10', 'x13')
# ('x2', 'x4', 'x6', 'x10', 'x14')
# ('x2', 'x4', 'x6', 'x11', 'x12')
# ('x2', 'x4', 'x6', 'x11', 'x13')
# ('x2', 'x4', 'x6', 'x11', 'x14')
# ('x2', 'x4', 'x7', 'x9', 'x12')
# ('x2', 'x4', 'x7', 'x9', 'x13')
# ('x2', 'x4', 'x7', 'x9', 'x14')
# ('x2', 'x4', 'x7', 'x10', 'x12')
# ('x2', 'x4', 'x7', 'x10', 'x13')
# ('x2', 'x4', 'x7', 'x10', 'x14')
# ('x2', 'x4', 'x7', 'x11', 'x12')
# ('x2', 'x4', 'x7', 'x11', 'x13')
# ('x2', 'x4', 'x7', 'x11', 'x14')
# ('x2', 'x4', 'x8', 'x9', 'x12')
# ('x2', 'x4', 'x8', 'x9', 'x13')
# ('x2', 'x4', 'x8', 'x9', 'x14')
# ('x2', 'x4', 'x8', 'x10', 'x12')
# ('x2', 'x4', 'x8', 'x10', 'x13')
# ('x2', 'x4', 'x8', 'x10', 'x14')
# ('x2', 'x4', 'x8', 'x11', 'x12')
# ('x2', 'x4', 'x8', 'x11', 'x13')
# ('x2', 'x4', 'x8', 'x11', 'x14')
# ('x2', 'x5', 'x6', 'x9', 'x12')
# ('x2', 'x5', 'x6', 'x9', 'x13')
# ('x2', 'x5', 'x6', 'x9', 'x14')
# ('x2', 'x5', 'x6', 'x10', 'x12')
# ('x2', 'x5', 'x6', 'x10', 'x13')
# ('x2', 'x5', 'x6', 'x10', 'x14')
# ('x2', 'x5', 'x6', 'x11', 'x12')
# ('x2', 'x5', 'x6', 'x11', 'x13')
# ('x2', 'x5', 'x6', 'x11', 'x14')
# ('x2', 'x5', 'x7', 'x9', 'x12')
# ('x2', 'x5', 'x7', 'x9', 'x13')
# ('x2', 'x5', 'x7', 'x9', 'x14')
# ('x2', 'x5', 'x7', 'x10', 'x12')
# ('x2', 'x5', 'x7', 'x10', 'x13')
# ('x2', 'x5', 'x7', 'x10', 'x14')
# ('x2', 'x5', 'x7', 'x11', 'x12')
# ('x2', 'x5', 'x7', 'x11', 'x13')
# ('x2', 'x5', 'x7', 'x11', 'x14')
# ('x2', 'x5', 'x8', 'x9', 'x12')
# ('x2', 'x5', 'x8', 'x9', 'x13')
# ('x2', 'x5', 'x8', 'x9', 'x14')
# ('x2', 'x5', 'x8', 'x10', 'x12')
# ('x2', 'x5', 'x8', 'x10', 'x13')
# ('x2', 'x5', 'x8', 'x10', 'x14')
# ('x2', 'x5', 'x8', 'x11', 'x12')
# ('x2', 'x5', 'x8', 'x11', 'x13')
# ('x2', 'x5', 'x8', 'x11', 'x14')

# %%
hotels = create_variables(15)

places = ['d_airport','d_volcan_poás','d_monteverde','d_tapati','d_corcovado']

result = best_route_v0(hotels,places,_df)

# %% [markdown]
# #Check Results
#
# We can see that the algorithm work and we got better results than using the simplex method.

# %%
result
# Out:
# (('x0', 'x4', 'x6', 'x10', 'x14'), 71182.5)

# %%
_df['x4']['_x6']+_df['x6']['_x10']+_df['x10']['_x14']+_df['x14']['_x0']+_df[places[0]]['_x0']+_df[places[1]]['_x4']+_df[places[2]]['_x6']+_df[places[3]]['_x10']+_df[places[4]]['_x14']
# Out:
# 71182.5

# %%
dr = _df.iloc[[0,4,6,10,14]]

dr
# Out:
#         Province      Canton         District  ...      x12      x13      x14
# _x0     Alajuela    Alajuela      Río Segundo  ...  23075.7  19846.2  17492.6
# _x4     Alajuela      Grecia       San Isidro  ...  24734.4  21504.9  19151.3
# _x6   Puntarenas  Puntarenas      Monte Verde  ...  26974.1  23744.6  21391.0
# _x10     Cartago     Cartago     Dulce Nombre  ...  24893.4  21663.9  19310.3
# _x14  Puntarenas         Osa  Piedras Blancas  ...   6021.1   5434.6      0.0
#
# [5 rows x 27 columns]

# %%
lnga,lata = -84.2041127746699,9.997933974047806
lngv,latv = -84.24278716302729,10.196943409958461
lngm,latm  = -84.79402582701236,10.31792333245692
lngt,latt  = -83.77709939226695,9.761592197168095
lngc,latc = -83.55879213348997,8.566233468363677

map_res = folium.Map(location=[lata, lnga], zoom_start=10)
    
folium.CircleMarker(
        location = [lata, lnga],
        radius=15,
        popup= 'Airport',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_res)

folium.CircleMarker(
        location = [latv, lngv],
        radius=15,
        popup= 'Volcan',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_res)

folium.CircleMarker(
        location = [latm, lngm],
        radius=15,
        popup= 'Monteverde',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_res)

folium.CircleMarker(
        location = [latt, lngt],
        radius=15,
        popup= 'Tapati',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_res)  

folium.CircleMarker(
        location = [latc, lngc],
        radius=15,
        popup= 'Corcovado',
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_res)        

for index,row in dr.iterrows():

      lat = row['latitude']
      lng = row['longitude']
      label = row['District']
      folium.CircleMarker(
        location = [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_res)       


map_res
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_a8bc10f516ed4a0eaf4b92358d9773f7%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a8bc10f516ed4a0eaf4b92358d9773f7%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_a8bc10f516ed4a0eaf4b92358d9773f7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_a8bc10f516ed4a0eaf4b92358d9773f7%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B9.997933974047806%2C%20-84.2041127746699%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_65fc25b71ae3437aa44a9c7b7a14cd93%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A ...

# %% [markdown]
# # Real Case
